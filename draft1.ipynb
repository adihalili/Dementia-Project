# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt  #for reshaping graph size
import seaborn as sns  # for creating the graphs

# %%
url= 'https://raw.githubusercontent.com/adihalili/project1/main/dementia_patients_health_data.csv'
dmn_df= pd.read_csv(url)
dmn_df.head()
# Out:
#    Diabetic  AlcoholLevel  HeartRate  BloodOxygenLevel  BodyTemperature  \
# 0         1      0.084974         98         96.230743        36.224852
# 1         0      0.016973         78         93.032122        36.183874
# 2         0      0.009000         89         93.566504        37.326321
# 3         0      0.086437         60         93.906510        37.030620
# 4         1      0.150747         67         97.508994        36.062121
#
#       Weight  MRI_Delay Prescription  Dosage in mg  Age  ...  Smoking_Status  \
# 0  57.563978  36.421028          NaN           NaN   60  ...  Current Smoker
# 1  56.832335  31.157633  Galantamine          12.0   61  ...   Former Smoker
# 2  59.759066  37.640435          NaN           NaN   69  ...   Former Smoker
# 3  58.266471  50.673992    Donepezil          23.0   78  ...    Never Smoked
# 4  67.705027  27.810601    Memantine          20.0   77  ...    Never Smoked
#
#     APOE_ε4  Physical_Activity Depression_Status Cognitive_Test_Scores  \
# 0  Negative          Sedentary                No                    10
# 1  Positive  Moderate Activity                No                     1
# 2  Negative  Moderate Activity                No                     8
# 3  Negative      Mild Activity               Yes                     5
# 4  Positive      Mild Activity                No                     0
#
#   Medication_History      Nutrition_Diet Sleep_Quality  \
# 0                 No       Low-Carb Diet          Poor
# 1                Yes       Low-Carb Diet          Poor
# 2                 No  Mediterranean Diet          Poor
# 3                Yes       Balanced Diet          Poor
# 4                Yes       Low-Carb Diet          Good
#
#    Chronic_Health_Conditions Dementia
# 0                   Diabetes        0
# 1              Heart Disease        1
# 2              Heart Disease        0
# 3               Hypertension        1
# 4                   Diabetes        1
#
# [5 rows x 24 columns]

# %%
dmn_df["Chronic_Health_Conditions"].unique()
# Out:
# array(['Diabetes', 'Heart Disease', 'Hypertension', nan], dtype=object)

# %%
dmn_df.isnull().sum()
# Out:
# Diabetic                       0
# AlcoholLevel                   0
# HeartRate                      0
# BloodOxygenLevel               0
# BodyTemperature                0
# Weight                         0
# MRI_Delay                      0
# Prescription                 515
# Dosage in mg                 515
# Age                            0
# Education_Level                0
# Dominant_Hand                  0
# Gender                         0
# Family_History                 0
# Smoking_Status                 0
# APOE_ε4                        0
# Physical_Activity              0
# Depression_Status              0
# Cognitive_Test_Scores          0
# Medication_History             0
# Nutrition_Diet                 0
# Sleep_Quality                  0
# Chronic_Health_Conditions    179
# Dementia                       0
# dtype: int64

# %%
d_sick= dmn_df[dmn_df['Dementia']==1]
d_healthy= dmn_df[dmn_df['Dementia']==0]
women= dmn_df[dmn_df['Gender']=='Female']
men= dmn_df[dmn_df['Gender']=='Male']
d_sick
# Out:
#      Diabetic  AlcoholLevel  HeartRate  BloodOxygenLevel  BodyTemperature  \
# 1           0      0.016973         78         93.032122        36.183874
# 3           0      0.086437         60         93.906510        37.030620
# 4           1      0.150747         67         97.508994        36.062121
# 5           1      0.114028         94         94.546754        36.678071
# 6           1      0.016194         90         96.423361        37.024630
# ..        ...           ...        ...               ...              ...
# 992         1      0.139464         84         94.083170        36.053883
# 993         0      0.128752         78         90.727275        36.797570
# 994         1      0.002725         84         93.624111        37.039966
# 995         1      0.081825         87         93.851963        36.495134
# 998         0      0.037347         71         91.298580        37.037202
#
#         Weight  MRI_Delay  Prescription  Dosage in mg  Age  ...  \
# 1    56.832335  31.157633   Galantamine          12.0   61  ...
# 3    58.266471  50.673992     Donepezil          23.0   78  ...
# 4    67.705027  27.810601     Memantine          20.0   77  ...
# 5    66.592329  21.154863  Rivastigmine           1.5   67  ...
# 6    83.976553  11.350612     Donepezil          10.0   87  ...
# ..         ...        ...           ...           ...  ...  ...
# 992  53.488677  34.187079     Memantine          10.0   76  ...
# 993  96.158804  32.129454  Rivastigmine           1.5   77  ...
# 994  80.768869  46.525974   Galantamine          12.0   83  ...
# 995  50.380106  42.318663     Donepezil          10.0   88  ...
# 998  95.322210  17.445715     Memantine          20.0   62  ...
#
#     Smoking_Status   APOE_ε4  Physical_Activity Depression_Status  \
# 1    Former Smoker  Positive  Moderate Activity                No
# 3     Never Smoked  Negative      Mild Activity               Yes
# 4     Never Smoked  Positive      Mild Activity                No
# 5    Former Smoker  Positive      Mild Activity               Yes
# 6     Never Smoked  Positive      Mild Activity                No
# ..             ...       ...                ...               ...
# 992   Never Smoked  Positive      Mild Activity                No
# 993  Former Smoker  Negative      Mild Activity                No
# 994  Former Smoker  Positive  Moderate Activity                No
# 995   Never Smoked  Positive      Mild Activity                No
# 998   Never Smoked  Positive          Sedentary               Yes
#
#     Cognitive_Test_Scores Medication_History      Nutrition_Diet  \
# 1                       1                Yes       Low-Carb Diet
# 3                       5                Yes       Balanced Diet
# 4                       0                Yes       Low-Carb Diet
# 5                       1                 No       Low-Carb Diet
# 6                       7                 No  Mediterranean Diet
# ..                    ...                ...                 ...
# 992                     5                Yes  Mediterranean Diet
# 993                     7                Yes       Low-Carb Diet
# 994                     7                 No       Low-Carb Diet
# 995                     5                 No       Balanced Diet
# 998                     2                 No       Low-Carb Diet
#
#     Sleep_Quality  Chronic_Health_Conditions Dementia
# 1            Poor              Heart Disease        1
# 3            Poor               Hypertension        1
# 4            Good                   Diabetes        1
# 5            Poor                   Diabetes        1
# 6            Poor                   Diabetes        1
# ..            ...                        ...      ...
# 992          Poor                   Diabetes        1
# 993          Good               Hypertension        1
# 994          Poor                   Diabetes        1
# 995          Poor                   Diabetes        1
# 998          Good                        NaN        1
#
# [485 rows x 24 columns]

# %%
fig, axes = plt.subplots(figsize=(18, 4), ncols=2)
sns.countplot(data = men, x="Education_Level",hue="Dementia", order= ['No School', 'Primary School', 'Secondary School', 'Diploma/Degree'], ax = axes[0])
sns.countplot(data = women, x="Education_Level",hue="Dementia", order= ['No School', 'Primary School', 'Secondary School', 'Diploma/Degree'], ax = axes[1])
# Out:
# <Axes: xlabel='Education_Level', ylabel='count'>

# %%
fig, axes = plt.subplots(figsize=(18, 4), ncols=2)
sns.countplot(data = men, x="Education_Level",hue="Dementia", order= ['No School', 'Primary School', 'Secondary School', 'Diploma/Degree'], ax = axes[0])
sns.countplot(data = women, x="Education_Level",hue="Dementia", order= ['No School', 'Primary School', 'Secondary School', 'Diploma/Degree'], ax = axes[1])
# Out:
# <Axes: xlabel='Education_Level', ylabel='count'>

# %%
fig, axes = plt.subplots(figsize=(10, 3), ncols=2)
sns.countplot(data = women[women['Dementia']==1], x="Physical_Activity",hue="Dementia", ax = axes[0])
sns.countplot(data = men[men['Dementia']==1], x="Physical_Activity",hue="Dementia", ax = axes[1])
# Out:
# <Axes: xlabel='Physical_Activity', ylabel='count'>

# %%
fig, axes = plt.subplots(figsize=(10, 3), ncols=2)
sns.histplot(data = women[women['Dementia']==0], x="Physical_Activity",hue="Dementia", ax = axes[0])
sns.countplot(data = men[men['Dementia']==0], x="Physical_Activity",hue="Dementia", ax = axes[1])
# Out:
# <Axes: xlabel='Physical_Activity', ylabel='count'>

# %%
sns.regplot(data=dmn_df, y="Age", x="BodyTemperature")
# Out:
# <Axes: xlabel='HeartRate', ylabel='Age'>

# %%
dmn_df['Sleep_Quality'].info
# Out:
# <bound method Series.info of 0      Poor
# 1      Poor
# 2      Poor
# 3      Poor
# 4      Good
#        ...
# 995    Poor
# 996    Poor
# 997    Good
# 998    Good
# 999    Good
# Name: Sleep_Quality, Length: 1000, dtype: object>

# %%
plt.figure(figsize=(7,5))

sns.countplot(x='APOE_ε4', hue='Dementia', data=dmn_df)
# Out:
# <Axes: xlabel='APOE_ε4', ylabel='count'>

# %%
plt.figure(figsize=(6,3))
sns.countplot(dmn_df, x='Cognitive_Test_Scores', hue='Dementia')
# Out:
# <Axes: xlabel='Cognitive_Test_Scores', ylabel='count'>

# %%
plt.figure(figsize = (8, 4), facecolor = "white")
sns.boxplot(dmn_df, x = 'Dementia', y = 'Cognitive_Test_Scores')
plt.show()

# %%
sns.countplot(d_sick[d_sick['Cognitive_Test_Scores']==7], x='Education_Level')
# Out:
# <Axes: xlabel='Education_Level', ylabel='count'>

# %%
sns.countplot(d_sick[d_sick['Education_Level']=='Diploma/Degree'], x='Cognitive_Test_Scores')
# Out:
# <Axes: xlabel='Cognitive_Test_Scores', ylabel='count'>

# %%
בחרנו להתמקד בחמישים האנשים שחולים ועשו תואר ראשון ורצינו לבדוק מה היו התוצאות שלהם במבחנים הקוגניטיביים
כלומר לראות אם זה שההשכלה שלהם גבוהה יותר עזרה להם למרות המחלה להוציא ציונין טובים יותר
בהחלט נוכל לראו פה מגמה(אם כי לא ברורה בגלל שהמחלה הזו לא אחידה) של רוב ציונים גבוהים יותר לפי רמת ההשכלה
כלומר, ניתן להסיק שעל אף שעדיין חלו, רוב האנשים שעשו תואר ראשון כנראה בתפקוד גבוה יותר כי הצליחו להשיג ציונים גבוהים במבחן קוגניציה

# %%
sns.countplot(d_sick[d_sick['Cognitive_Test_Scores']==7], x='Education_Level')
# Out:
# <Axes: xlabel='Education_Level', ylabel='count'>

# %%
plt.figure(figsize=(6,3))
sns.countplot(dmn_df, x='Cognitive_Test_Scores', hue='Depression_Status')
# Out:
# <Axes: xlabel='Cognitive_Test_Scores', ylabel='count'>

# %%
graph = sns.FacetGrid(dmn_df, col ="Education_Level",  hue ="Age") 
graph.map(plt.scatter, 'Primary_School', 'Secondary_School',  edgecolor ="w").add_legend() 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[147], line 2
#       1 graph = sns.FacetGrid(dmn_df, col ="Education_Level",  hue ="Age")
# ----> 2 graph.map(plt.scatter, 'Primary_School', 'Secondary_School',  edgecolor ="w").add_legend()
#       3 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\axisgrid.py:742, in FacetGrid.map(self, func, *args, **kwargs)
#     739     kwargs["label"] = utils.to_utf8(self.hue_names[hue_k])
#     741 # Get the actual data we are going to plot with
# --> 742 plot_data = data_ijk[list(args)]
#     743 if self._dropna:
#     744     plot_data = plot_data.dropna()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5938, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5936     if use_interval_msg:
#    5937         key = list(key)
# -> 5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Primary_School', 'Secondary_School'], dtype='object')] are in the [columns]"

# %%
dmn_df.pivot_table('Dementia', index= 'Sleep_Quality', columns= 'Education_Level', aggfunc= 'mean')
# Out:
# Education_Level  Diploma/Degree  No School  Primary School  Secondary School
# Sleep_Quality
# Good                   0.293103   0.690141        0.410256          0.528169
# Poor                   0.361702   0.583333        0.520619          0.493827

# %%
dmn_df.pivot_table('Dementia' ,index= 'Nutrition_Diet', columns= 'Education_Level', values= ['Dementia', 'Cognitive_Test_Scores'], aggfunc= 'mean')
# Out:
#                    Cognitive_Test_Scores                           \
# Education_Level           Diploma/Degree No School Primary School
# Nutrition_Diet
# Balanced Diet                   7.361702  5.780000       6.877049
# Low-Carb Diet                   7.568182  5.365385       6.585185
# Mediterranean Diet              7.098361  5.433962       6.295455
#
#                                           Dementia                           \
# Education_Level    Secondary School Diploma/Degree No School Primary School
# Nutrition_Diet
# Balanced Diet              6.203540       0.297872  0.580000       0.450820
# Low-Carb Diet              5.868687       0.340909  0.692308       0.437037
# Mediterranean Diet         6.239130       0.360656  0.622642       0.507576
#
#
# Education_Level    Secondary School
# Nutrition_Diet
# Balanced Diet              0.495575
# Low-Carb Diet              0.525253
# Mediterranean Diet         0.510870

# %%
dmn_df.groupby(['Nutrition_Diet', 'Smoking_Status', 'APOE_ε4'])['Dementia'].mean()
# Out:
# Nutrition_Diet      Smoking_Status  APOE_ε4
# Balanced Diet       Current Smoker  Negative    0.000000
#                                     Positive    0.000000
#                     Former Smoker   Negative    0.276596
#                                     Positive    0.652174
#                     Never Smoked    Negative    0.177778
#                                     Positive    0.617021
# Low-Carb Diet       Current Smoker  Negative    0.000000
#                                     Positive    0.000000
#                     Former Smoker   Negative    0.195122
#                                     Positive    0.681034
#                     Never Smoked    Negative    0.155556
#                                     Positive    0.653846
# Mediterranean Diet  Current Smoker  Negative    0.000000
#                                     Positive    0.000000
#                     Former Smoker   Negative    0.200000
#                                     Positive    0.696970
#                     Never Smoked    Negative    0.142857
#                                     Positive    0.704918
# Name: Dementia, dtype: float64

# %%
g = dmn_df.pivot_table('Dementia', index= 'Education_Level', columns= 'APOE_ε4', aggfunc= 'mean')
g
# Out:
# APOE_ε4           Negative  Positive
# Education_Level
# Diploma/Degree    0.035088  0.515789
# No School         0.225000  0.773913
# Primary School    0.200000  0.590909
# Secondary School  0.166667  0.640909

# %%
plt.figure(figsize=(8,4))
#plt.xticks(rotation=90)
ax = sns.barplot(data = dmn_df, x='Education_Level', y='Dementia', hue = 'APOE_ε4',errorbar=None)
ax.set(ylabel='average Dementia')
plt.legend(title='APOE_ε4', loc=('upper right')) #the legend position
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.heatmap(g, cmap= 'coolwarm', center= 0, annot = True)
# Out:
# <Axes: xlabel='APOE_ε4', ylabel='Education_Level'>

# %%
dmn_df.pivot_table('Dementia', index= 'Nutrition_Diet', columns= 'APOE_ε4', aggfunc= 'mean')
# Out:
# APOE_ε4             Negative  Positive
# Nutrition_Diet
# Balanced Diet       0.198113  0.588496
# Low-Carb Diet       0.150000  0.639130
# Mediterranean Diet  0.140000  0.651261

# %%
dmn_df.pivot_table('Dementia', index= 'Education_Level', columns= 'Medication_History', aggfunc= 'mean')
# Out:
# Medication_History        No       Yes
# Education_Level
# Diploma/Degree      0.273973  0.392405
# No School           0.615385  0.649351
# Primary School      0.463918  0.466667
# Secondary School    0.539007  0.484663

# %%
dmn_df.pivot_table('Dementia', index= 'Education_Level', columns= 'Nutrition_Diet', aggfunc= 'mean')
# Out:
# Nutrition_Diet    Balanced Diet  Low-Carb Diet  Mediterranean Diet
# Education_Level
# Diploma/Degree         0.297872       0.340909            0.360656
# No School              0.580000       0.692308            0.622642
# Primary School         0.450820       0.437037            0.507576
# Secondary School       0.495575       0.525253            0.510870

# %%
dmn_df.pivot_table('Dementia', index= 'Education_Level', columns= 'Chronic_Health_Conditions', aggfunc= 'mean')
# Out:
# Chronic_Health_Conditions  Diabetes  Heart Disease  Hypertension
# Education_Level
# Diploma/Degree             0.378049       0.208333      0.318182
# No School                  0.666667       0.473684      0.580645
# Primary School             0.447761       0.477612      0.482143
# Secondary School           0.570470       0.422222      0.454545

# %%
dmn_df.pivot_table('Dementia', index= 'Education_Level', columns= 'Chronic_Health_Conditions', aggfunc= 'mean')
plt.figure(figsize=(8,4))
ax = sns.barplot(data= dmn_df, x= 'Education_Level', y= 'Dementia', hue= 'Chronic_Health_Conditions', errorbar=None)
ax.set(ylabel='average Dementia')
plt.legend(title='Chronic_Health_Conditions', loc=('upper right')) #the legend position
plt.show()

# %%
sns.countplot(data = dmn_df, x="Education_Level",hue="Dementia")
# Out:
# <Axes: xlabel='Education_Level', ylabel='count'>

# %%
fig, axes = plt.subplots(figsize=(20, 7), ncols=2)
sns.boxplot(data = d_sick, x="Dementia",y="Age", ax = axes[0])
sns.countplot(data = d_sick, x="Age",hue="APOE_ε4", ax = axes[1])
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
המדיאן של גיל האנשים שחולים בדמנציה הוא כ-80 שנה.
רוב האנשים שחולים בדמנציה הם מעל גיל 65.
ישנם מספר קטן של אנשים שחולים בדמנציה בגיל צעיר מ-65.
ישנם מספר קטן של אנשים שחולים בדמנציה בגיל מעל 90.

# %%
fig, axes = plt.subplots(figsize=(18, 4), ncols=4)

sns.boxplot(data = d_sick, x = 'Chronic_Health_Conditions', y = 'Age', ax = axes[0])
sns.boxplot(data = d_sick, x = 'Smoking_Status', y = 'Age', ax = axes[1])
sns.boxplot(data = d_sick, x = 'Physical_Activity', y = 'Age', ax = axes[2])
sns.boxplot(data = d_sick, x = 'Cognitive_Test_Scores', y = 'Age', ax = axes[3])


plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(figsize=(18, 4), ncols=4)

sns.boxplot(data = d_healthy, x = 'Chronic_Health_Conditions', y = 'Age', ax = axes[0])
sns.boxplot(data = d_healthy, x = 'Smoking_Status', y = 'Age', ax = axes[1])
sns.boxplot(data = d_healthy, x = 'Physical_Activity', y = 'Age', ax = axes[2])
sns.boxplot(data = d_healthy, x = 'Cognitive_Test_Scores', y = 'Age', ax = axes[3])


plt.tight_layout()
plt.show()

# %%
dmn_df['Education_Level'].unique()
# Out:
# array(['Primary School', 'Secondary School', 'No School',
#        'Diploma/Degree'], dtype=object)

# %%
dmn_df['Sleep_Quality'].unique()
# Out:
# array(['Poor', 'Good'], dtype=object)

# %%
dmn_df['Smoking_Status'].unique()
# Out:
# array(['Current Smoker', 'Former Smoker', 'Never Smoked'], dtype=object)

# %%
#dmn_df['Education_Level']= dmn_df['Education_Level'].replace(['No School', 'Primary School','Secondary School', 'Diploma/Degree'], [0,1,2,3])
#dmn_df['Sleep_Quality']= dmn_df['Sleep_Quality'].replace(['Poor','Good'], [0,1])
#dmn_df['Smoking_Status']= dmn_df['Sleep_Quality'].replace(['Current Smoker', 'Former Smoker', 'Never Smoked'], [2, 1, 0])

# %%
corrs= dmn_df.corr(method= 'kendall', numeric_only= True)
plt.figure(figsize=(20,10))
sns.heatmap(corrs, cmap= 'coolwarm', center= 0, annot = True)
# Out:
# <Axes: >

# %%
smoking_sleep= ['Smoking_Status', 'Education_Level', 'Cognitive_Test_Scores', 'Sleep_Quality']
corr = dmn_df[smoking_sleep].corr(method= 'kendall', numeric_only= True)
fig, ax = plt.subplots(figsize=(20,5)) 
sns.heatmap(corr,annot=True, cmap = 'Blues', linewidth = 0.6)
plt.title('Correlation matrix')
plt.show()
